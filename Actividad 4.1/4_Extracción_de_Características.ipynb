# %% [markdown]
# <a href="https://colab.research.google.com/github/freddy-7/TI3002C/blob/main/5_Extracci%C3%B3n_de_Caracter%C3%ADsticas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importamos las librerias pandas, numpy y matplotlib respectivamente
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Carga desde un archivo .csv sin indice
bpiso= pd.read_csv('C:\\Users\\maria\\OneDrive\\Escritorio\\extraccion datos\\extraccion caracteristicas\\extraccion_caracteristicas\\Actividad 4.1\\Analisis GAC Full7agosto 2026(Bitacora de Piso).csv')

# %%
#Verificamos información del DataFrame
bpiso.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 30 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Fecha                                       198 non-null    str
#  1   Nombre Cliente                              197 non-null    str
#  2   Telefono                                    0 non-null      float64
#  3   Asesor                                      196 non-null    str
#  4   Esatus Lead                                 197 non-null    str
#  5   PDM                                         234 non-null    bool
#  6   SDC                                         216 non-null    object
#  7   Estatus de SDC                              2 non-null      str
#  8   Venta                                       216 non-null    object
#  9   Temperatura                                 10 non-null     str
# ...

# %%
#Imprimo los primeros 5 registro del dataframe
bpiso.head()
# Out:
#         Fecha         Nombre Cliente   Telefono    Asesor  Esatus Lead    PDM  \
# 0  04/01/2025  Ubaldo Cruz Hernandez         NaN   Aurelio      Activo   True
# 1  04/01/2025          Olivia Cabello        NaN     Pedro      Activo  False
# 2  04/02/2025      Ana Laura Espinoza        NaN  Mauricio      Activo   True
# 3  04/02/2025          Elvis Sanchez         NaN   Aurelio      Activo  False
# 4  04/03/2025   Ariel Fernando López         NaN     Alan       Activo   True
#
#      SDC Estatus de SDC   Venta       Temperatura   ... Unnamed: 20  \
# 0  False             NaN  False   Lead InteresBajo  ...         NaN
# 1  False             NaN  False   Lead InteresBajo  ...         NaN
# 2   True       Analisis    True  Lead Interes Alto  ...         NaN
# 3  False             NaN  False   Lead InteresBajo  ...         NaN
# 4  False             NaN  False                NaN  ...         NaN
#
#   Unnamed: 21 Unnamed: 22 Unnamed: 23 Unnamed: 24 Unnamed: 25 Unnamed: 26  \
# ...

# %% [markdown]
# Asesor

# %%
#Obtengo un análisis univariado de las variables categóricas
Tabla_freq = bpiso['Asesor '].value_counts().reset_index()
Tabla_freq
# Out:
#                   Asesor   count
# 0                 Aurelio     34
# 1                Mauricio     28
# 2                   Pedro     25
# 3                  Victor     16
# 4                   Alan      13
# 5         Pedro González      11
# 6          Aurelio Torres     10
# 7          Alan González       7
# 8                Ricardo       5
# 9                 Ricardo      5
# 10      Mauricio Vazquez       5
# 11                Victor       4
# 12                  Nancy      3
# 13        Aurelio Torres       3
# 14         Ricardo Silva       3
# 15                Eduardo      2
# 16          Alan González      2
# 17                   Casa      2
# 18         Alan Gonzalez       2
# 19            Marcos Coca      2
# 20                  Laura      1
# 21                AUrelio      1
# 22        Nancy OLascoaga      1
# 23                   Alan      1
# 24          Pedro Antonio      1
# 25  Victor Manuel Sanchez      1
# 26       Mauricio Vazquez      1
# ...

# %%
#Obtengo un filtro de los valores más reelevantes de la variable categórica seleccionada
Filtro= Tabla_freq[Tabla_freq['count']>4]
Filtro
# Out:
#               Asesor   count
# 0             Aurelio     34
# 1            Mauricio     28
# 2               Pedro     25
# 3              Victor     16
# 4               Alan      13
# 5     Pedro González      11
# 6      Aurelio Torres     10
# 7      Alan González       7
# 8            Ricardo       5
# 9             Ricardo      5
# 10  Mauricio Vazquez       5

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('Asesor ')
Filtro_index
# Out:
#                    count
# Asesor
# Aurelio               34
# Mauricio              28
# Pedro                 25
# Victor                16
# Alan                  13
# Pedro González        11
# Aurelio Torres        10
# Alan González          7
# Ricardo                5
# Ricardo                5
# Mauricio Vazquez       5

# %%
#Realizamos grafico de barras del dataframe filtrado
Filtro_index.plot(kind = 'bar', width=0.8, figsize=(10,4), color= "pink", edgecolor="purple")
plt.title('Asesores con más de 4 registros')
plt.xlabel('Asesores')
plt.ylabel('Ventas')
# Out:
# Text(0, 0.5, 'Ventas')

# %% [markdown]
# PDM (Prueba de manejo)

# %%
#Obtengo un análisis univariado de las variables categóricas
Tabla_freq1 = bpiso['PDM'].value_counts().reset_index()
Tabla_freq1
# Out:
#      PDM  count
# 0  False    159
# 1   True     75

# %%
# Primero cambiamos las etiquetas
Tabla_freq1["PDM"] = Tabla_freq1["PDM"].replace({
    False: "Sin Prueba de Manejo",
    True: "Con Prueba de Manejo"
})

# Después hacemos la gráfica
Tabla_freq1.plot(
    kind="pie",
    y="count",
    labels=Tabla_freq1["PDM"],
    figsize=(10, 5),
    shadow=True,
    autopct="%0.1f%%"
)
# Out:
# <Axes: >

# %% [markdown]
# SDC

# %%
#Obtengo un análisis univariado de las variables categóricas
Tabla_freq2 = bpiso['SDC'].value_counts().reset_index()
Tabla_freq2
# Out:
#      SDC  count
# 0  False    212
# 1   True      4

# %%
ax = Tabla_freq2.plot(
    kind="pie",
    y="count",
    labels=Tabla_freq2['SDC'],
    figsize=(8, 8),
    shadow=True,
    autopct="%0.1f%%",
    legend=False
)

ax.set_ylabel("")
ax.set_title("Prueba de manejo realizada")
# Out:
# Text(0.5, 1.0, 'Prueba de manejo realizada')

# %% [markdown]
# Ventas

# %%
#Obtengo un análisis univariado de las variables categóricas
Tabla_freq3 = bpiso['Venta'].value_counts().reset_index()
Tabla_freq3
# Out:
#    Venta  count
# 0  False    212
# 1   True      4

# %%
Tabla_freq3["Venta"] = Tabla_freq3["Venta"].replace({
    False: "Venta no realizada",
    True: "Venta realizada"
})
ax = Tabla_freq3.plot(
    kind="pie",
    y="count",
    labels=Tabla_freq3['Venta'],
    figsize=(8, 8),
    shadow=True,
    autopct="%0.1f%%",
    legend=False
)

ax.set_ylabel("")
ax.set_title("Venta realizada")
# Out:
# Text(0.5, 1.0, 'Venta realizada')

# %% [markdown]
# Inter Gerente

# %%
#Obtengo un análisis univariado de las variables categóricas
Tabla_freq4 = bpiso['Inter Gerente'].value_counts().reset_index()
Tabla_freq4
# Out:
#    Inter Gerente  count
# 0          False    185
# 1           True     31

# %%
Tabla_freq4["Inter Gerente"] = Tabla_freq4["Inter Gerente"].replace({
    False: "El gerente no realizó la intervención",
    True: "El gerente realizó la intervención"
})
ax = Tabla_freq4.plot(
    kind="pie",
    y="count",
    labels=Tabla_freq4['Inter Gerente'],
    figsize=(8, 8),
    shadow=True,
    autopct="%0.1f%%",
    legend=False
)

ax.set_ylabel("")
ax.set_title("Intervención del gerente")
# Out:
# Text(0.5, 1.0, 'Intervención del gerente')

# %% [markdown]
# Estatus del lead

# %%
bpiso.columns
# Out:
# Index(['Fecha', 'Nombre Cliente ', 'Telefono ', 'Asesor ', 'Esatus Lead',
#        'PDM', 'SDC', 'Estatus de SDC ', 'Venta', 'Temperatura ',
#        'Inter Gerente', '¿Por que no hubo prueba de manejo?',
#        '¿Por que no hubo Solicitud de credito?',
#        '¿Por que no hubo intervencion del Gerente?',
#        '¿Por que no hubo proceso wow?',
#        '¿Por que no se ha formalizado la compra?',
#        '5 porques clientes de piso ', 'Comentarios', 'Unnamed: 18',
#        'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22',
#        'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26',
#        'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29'],
#       dtype='str')

# %%
#Obtengo un análisis univariado de las variables categóricas
Tabla_freq5 = bpiso['Esatus Lead'].value_counts().reset_index()
Tabla_freq5
# Out:
#    Esatus Lead  count
# 0       Activo    157
# 1      Cerrado     11
# 2      Activo      11
# 3     Cerrado       7
# 4       Venta       3
# 5        Venta      3
# 6   Finalizado      2
# 7  Finalizado       2
# 8        venta      1

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('Esatus Lead')
Filtro_index
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[95], line 2
#       1 #Ajusto el indice de mi dataframe
# ----> 2 Filtro_index= Filtro.set_index('Esatus Lead')
#       3 Filtro_index
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\frame.py:6991, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    6987                     if not found:
#    6988                         missing.append(col)
#    6989
#    6990         if missing:
# -> 6991             raise KeyError(f"None of {missing} are in the columns")
#    6992
#    6993         if inplace:
#    6994             frame = self
#
# KeyError: "None of ['Esatus Lead'] are in the columns"

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('Estatus Lead')
Filtro_index
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[94], line 2
#       1 #Ajusto el indice de mi dataframe
# ----> 2 Filtro_index= Filtro.set_index('Estatus Lead')
#       3 Filtro_index
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\frame.py:6991, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    6987                     if not found:
#    6988                         missing.append(col)
#    6989
#    6990         if missing:
# -> 6991             raise KeyError(f"None of {missing} are in the columns")
#    6992
#    6993         if inplace:
#    6994             frame = self
#
# KeyError: "None of ['Estatus Lead'] are in the columns"

# %%
#Realizamos grafico de área del dataframe filtrado
Filtro_index.plot(kind='area', figsize=(10,4),alpha = 1)
# Out:
# <Axes: xlabel='214_customer_relationship_tools'>

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["count"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: >

# %% [markdown]
# **Determinación de Clases para datos agrupados** (de numericas a categoricas)

# %%
# Ajustar maximo de filas
pd.options.display.max_rows = None

# %%
#Corroboramos valores nulos
valores_nulos=Micro_Retailer.isnull().sum()
valores_nulos
# Out:
# _record_id                                                      0
# _title                                                          0
# _server_updated_at                                              0
# _updated_by                                                     0
# _geometry                                                       0
# _latitude                                                       0
# _longitude                                                      0
# 228_store_name                                                  0
# 229_store_picture                                               0
# 232_type_of_store                                               0
# 108_does_the_micro_retailer_has_a_barred_window_                0
# 99_does_the_micro_retailer_exhibits_products_outside_           0
# 102_does_the_micro_retailer_sells_fresh_products_               0
# 97_number_of_customers_in_store                                 0
# ...

# %%
#Calculamos el numero total de la población "n"
Micro_Retailer['_latitude']. info()
n=171
# Out:
# <class 'pandas.Series'>
# RangeIndex: 171 entries, 0 to 170
# Series name: _latitude
# Non-Null Count  Dtype
# --------------  -----
# 171 non-null    float64
# dtypes: float64(1)
# memory usage: 1.5 KB

# %%
#Obtenemos el limite superior y el límite inferior de la columna objetivo
Max=Micro_Retailer['_latitude'].max()
Min=Micro_Retailer['_latitude'].min()
Limites= [Min, Max]
Limites
# Out:
# [np.float64(18.9993095), np.float64(19.0752733)]

# %%
#Calculamos el rango R
R=Max-Min
R
# Out:
# np.float64(0.07596380000000025)

# %%
#Calculamos el número de Intervalos de Clase "ni", aplicando la regla de Sturges
ni= 1+3.32*np.log10(n)
ni
# Out:
# np.float64(8.41354708650195)

# %%
#Calculamos el Ancho del Intervalo "i"
i=R/ni
i
# Out:
# np.float64(0.009028748424296662)

# %% [markdown]
# **Creación de Categorias a partir de clases**

# %%
#Categorización de variables
#Declaramos 8 intervalos 
#Ajustamos los limites para que todos los valores sean incluidos en los intervalos
#Ampliamos los límites en una unidad sobre los decimales menos significativos
#con la intención de incluir los valores que caigan justo en los límites
intervalos=np.linspace(18.98, 19.076, 9)
intervalos
# Out:
# array([18.98 , 18.992, 19.004, 19.016, 19.028, 19.04 , 19.052, 19.064,
#        19.076])

# %%
#Creamos las categorías 
categorias= ["Categoría1(18.981°-18.992°)", "Categoría2(18.992°-19.004°)","Categoría3(19.004°-19.016°)", "Categoría4(19.016°-19.028°)",
             "Categoría5(19.028°-19.04°)", "Categoría6(19.04°-19.052°)","Categoría7(19.052°-19.064°)", "Categoría8(19.064°-19.076°)"]

# %%
#Finalmente creamos las categorías en la columna numérica
Micro_Retailer['_latitude']=pd.cut(x= Micro_Retailer['_latitude'], bins=intervalos, labels= categorias)
Micro_Retailer['_latitude']
# Out:
# 0      Categoría7(19.052°-19.064°)
# 1      Categoría7(19.052°-19.064°)
# 2      Categoría7(19.052°-19.064°)
# 3      Categoría7(19.052°-19.064°)
# 4      Categoría7(19.052°-19.064°)
# 5      Categoría7(19.052°-19.064°)
# 6      Categoría7(19.052°-19.064°)
# 7      Categoría7(19.052°-19.064°)
# 8      Categoría7(19.052°-19.064°)
# 9      Categoría7(19.052°-19.064°)
# 10     Categoría4(19.016°-19.028°)
# 11     Categoría4(19.016°-19.028°)
# 12     Categoría4(19.016°-19.028°)
# 13     Categoría4(19.016°-19.028°)
# 14     Categoría4(19.016°-19.028°)
# 15     Categoría4(19.016°-19.028°)
# 16     Categoría4(19.016°-19.028°)
# 17     Categoría4(19.016°-19.028°)
# 18     Categoría4(19.016°-19.028°)
# 19     Categoría4(19.016°-19.028°)
# 20      Categoría6(19.04°-19.052°)
# 21     Categoría8(19.064°-19.076°)
# 22     Categoría8(19.064°-19.076°)
# 23     Categoría7(19.052°-19.064°)
# 24     Categoría7(19.052°-19.064°)
# 25     Categoría7(19.052°-19.064°)
# 26     Categoría7(19.052°-19.064°)
# ...

# %%
#Obtengo un análisis univariado de las variables categóricas
Tabla_freq = Micro_Retailer['_latitude'].value_counts().reset_index()
Tabla_freq
# Out:
#                      _latitude  count
# 0  Categoría8(19.064°-19.076°)     47
# 1  Categoría4(19.016°-19.028°)     45
# 2   Categoría6(19.04°-19.052°)     31
# 3  Categoría7(19.052°-19.064°)     29
# 4   Categoría5(19.028°-19.04°)     10
# 5  Categoría3(19.004°-19.016°)      7
# 6  Categoría2(18.992°-19.004°)      2
# 7  Categoría1(18.981°-18.992°)      0

# %%
#Obtengo un filtro de los valores más reelevantes de la variable categórica seleccionada
Filtro= Tabla_freq[Tabla_freq['count']>0]
Filtro
# Out:
#                      _latitude  count
# 0  Categoría8(19.064°-19.076°)     47
# 1  Categoría4(19.016°-19.028°)     45
# 2   Categoría6(19.04°-19.052°)     31
# 3  Categoría7(19.052°-19.064°)     29
# 4   Categoría5(19.028°-19.04°)     10
# 5  Categoría3(19.004°-19.016°)      7
# 6  Categoría2(18.992°-19.004°)      2

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('_latitude')
Filtro_index
# Out:
#                              count
# _latitude
# Categoría8(19.064°-19.076°)     47
# Categoría4(19.016°-19.028°)     45
# Categoría6(19.04°-19.052°)      31
# Categoría7(19.052°-19.064°)     29
# Categoría5(19.028°-19.04°)      10
# Categoría3(19.004°-19.016°)      7
# Categoría2(18.992°-19.004°)      2

# %%
#Realizamos grafico de barras del dataframe filtrado
Filtro_index.plot(kind = 'bar', width=0.8, figsize=(10,4), color= "red", rot=45)
plt.title('Categorias por latitud')
plt.xlabel('rango de categorias')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')
